# %% [markdown]
# # Data Preprocessing of COUGHVID Dataset

# %% [markdown]
# ## Import Required Packages and Functions

# %%
from IPython.core.display import display
import numpy as np
from src.utils.preprocessing import import_data, standardize, create_multi_index
from src.utils.model.train import cross_validation
from sklearn.linear_model import LinearRegression
from sklearn.metrics import roc_auc_score

# %%
DATA_PATH = '../../data'

# %% [markdown]
# ## No segmentation data

# %%
df_features_no, df_labels_no = import_data(DATA_PATH, 'no')
df_features_coarse, df_labels_coarse = import_data(DATA_PATH, 'coarse')
df_features_fine, df_labels_fine = import_data(DATA_PATH, 'fine')

# %%
display(df_features_fine.describe())
display(df_labels_fine.describe())
# Out:
#         EEPD50_100  EEPD100_150  EEPD150_200  EEPD200_250  EEPD250_300  \
# count  7009.000000  7009.000000  7009.000000  7009.000000  7009.000000
# mean      4.351833     4.360964     4.412470     4.473962     4.503781
# std       1.278799     1.268739     1.276464     1.279308     1.303323
# min       1.000000     2.000000     1.000000     1.000000     2.000000
# 25%       4.000000     4.000000     4.000000     4.000000     4.000000
# 50%       4.000000     4.000000     4.000000     4.000000     4.000000
# 75%       5.000000     5.000000     5.000000     5.000000     5.000000
# max      17.000000    16.000000    16.000000    19.000000    20.000000
#
#        EEPD300_350  EEPD350_400  EEPD400_450  EEPD450_500  EEPD500_550  ...  \
# count  7009.000000  7009.000000  7009.000000  7009.000000  7009.000000  ...
# mean      4.521758     4.554002     4.593523     4.609645     4.618205  ...
# std       1.288280     1.326851     1.343370     1.341938     1.344187  ...
# min       1.000000     1.000000     1.000000     1.000000     1.000000  ...
# 25%       4.000000     4.000000     4.000000     4.000000     4.000000  ...
# 50%       4.000000     4.000000     4.000000     4.000000     4.000000  ...
# 75%       5.000000     5.000000     5.000000     5.000000     5.000000  ...
# max      18.000000    18.000000    23.000000    21.000000    18.000000  ...
#
#         PSD_225-425   PSD_450-550  PSD_1325-1600  PSD_1600-1900  \
# count  7.009000e+03  7.009000e+03    7009.000000    7009.000000
# mean   2.294744e-01  9.386090e-02       0.060585       0.048999
# std    1.638755e-01  9.938841e-02       0.075247       0.065329
# min    6.137005e-07  7.349431e-07       0.000001       0.000006
# 25%    1.042027e-01  2.945662e-02       0.014710       0.010312
# 50%    1.965166e-01  6.173333e-02       0.035651       0.026557
# 75%    3.172204e-01  1.223411e-01       0.076502       0.062026
# max    1.012291e+00  9.351590e-01       0.802540       0.961117
#
#        PSD_2500-2900  PSD_3100-3700          Age       Gender  Resp_Condition  \
# count   7.009000e+03   7.009000e+03  7009.000000  7009.000000     7009.000000
# mean    2.073963e-02   2.870803e-02    34.430037     0.389357        0.293480
# std     3.192758e-02   4.276823e-02    11.797510     0.451871        0.419252
# min     7.740565e-08   4.191298e-07     1.000000     0.000000        0.000000
# 25%     3.621972e-03   4.751279e-03    27.000000     0.000000        0.000000
# 50%     9.871327e-03   1.382644e-02    34.430037     0.000000        0.000000
# 75%     2.429375e-02   3.488572e-02    40.000000     1.000000        0.500000
# max     3.635824e-01   6.842158e-01    89.000000     1.000000        1.000000
#
#           Symptoms
# count  7009.000000
# mean      0.248966
# std       0.394210
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.500000
# max       1.000000
#
# [8 rows x 70 columns]
#              Label
# count  7009.000000
# mean      0.271223
# std       0.444622
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
X_fine = standardize(df_features_fine)
y_fine = df_labels_fine

# %%
display(X_fine.head())
display(y_fine.head())
# Out:
#                                               EEPD50_100  EEPD100_150  \
# subject                              file_id
# 008ba489-31ad-44d8-856b-fcf72369dc46 0          1.288931     1.291955
#                                      1         -1.057187    -1.072768
#                                      2         -0.275147    -0.284527
#                                      3         -0.275147    -0.284527
#                                      4         -0.275147    -0.284527
#
#                                               EEPD150_200  EEPD200_250  \
# subject                              file_id
# 008ba489-31ad-44d8-856b-fcf72369dc46 0           0.460313     -0.37051
#                                      1          -1.106628     -0.37051
#                                      2          -1.106628     -0.37051
#                                      3          -0.323158     -0.37051
#                                      4           0.460313     -0.37051
#
#                                               EEPD250_300  EEPD300_350  \
# subject                              file_id
# 008ba489-31ad-44d8-856b-fcf72369dc46 0           0.380761     0.371252
#                                      1          -0.386563     0.371252
#                                      2          -1.153887    -1.181317
#                                      3          -0.386563     0.371252
#                                      4          -0.386563     0.371252
#
#                                               EEPD350_400  EEPD400_450  \
# subject                              file_id
# 008ba489-31ad-44d8-856b-fcf72369dc46 0           1.089875     1.047051
#                                      1          -0.417561    -0.441848
#                                      2          -0.417561    -0.441848
#                                      3          -1.171280    -0.441848
#                                      4          -1.171280    -0.441848
#
#                                               EEPD450_500  EEPD500_550  ...  \
# subject                              file_id                            ...
# 008ba489-31ad-44d8-856b-fcf72369dc46 0           0.290910     1.028052  ...
#                                      1          -0.454334    -1.203940  ...
#                                      2          -0.454334    -0.459943  ...
#                                      3          -0.454334    -1.203940  ...
#                                      4          -0.454334    -1.203940  ...
#
#                                               PSD_225-425  PSD_450-550  \
# subject                              file_id
# 008ba489-31ad-44d8-856b-fcf72369dc46 0           1.030274    -0.678739
#                                      1           0.003524    -0.076663
#                                      2          -0.755062     0.870219
#                                      3           0.036878     0.282812
#                                      4           0.005610     0.259888
#
#                                               PSD_1325-1600  PSD_1600-1900  \
# subject                              file_id
# 008ba489-31ad-44d8-856b-fcf72369dc46 0            -0.627688      -0.239305
#                                      1            -0.488810      -0.615004
#                                      2            -0.344004      -0.654287
#                                      3             0.017244      -0.708112
#                                      4             0.117399      -0.708491
#
#                                               PSD_2500-2900  PSD_3100-3700  \
# subject                              file_id
# 008ba489-31ad-44d8-856b-fcf72369dc46 0             0.703362      -0.428456
#                                      1             1.107656      -0.404037
#                                      2             0.553499      -0.542342
#                                      3             0.305461      -0.634255
#                                      4             0.413321      -0.632874
#
#                                                    Age    Gender  \
# subject                              file_id
# 008ba489-31ad-44d8-856b-fcf72369dc46 0       -0.545072  1.351463
#                                      1       -0.545072  1.351463
#                                      2       -0.545072  1.351463
#                                      3       -0.545072  1.351463
#                                      4       -0.545072  1.351463
#
#                                               Resp_Condition  Symptoms
# subject                              file_id
# 008ba489-31ad-44d8-856b-fcf72369dc46 0             -0.700058 -0.631601
#                                      1             -0.700058 -0.631601
#                                      2             -0.700058 -0.631601
#                                      3             -0.700058 -0.631601
#                                      4             -0.700058 -0.631601
#
# [5 rows x 70 columns]
#                                               Label
# subject                              file_id
# 008ba489-31ad-44d8-856b-fcf72369dc46 0          1.0
#                                      1          1.0
#                                      2          1.0
#                                      3          1.0
#                                      4          1.0

# %%
auc_list = cross_validation(X_fine, y_fine, k=5, model=LinearRegression(), metric=roc_auc_score)
print(np.mean(auc_list))
# Out:
# 0.5937147158892685

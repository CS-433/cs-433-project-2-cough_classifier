# %% [markdown]
# ### Import libraries

# %%
from IPython.core.display import display
from src.utils.preprocessing import classic_preprocessing,standardize
from src.utils.get_data import import_data, split_experts
from src.utils.train import hyperparameter_tuning_cv
from src.utils.config import *
import pandas as pd

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Load Data

# %%
DATA_PATH = '../../data'
X_no, y_no = import_data(DATA_PATH, segmentation_type='no',
                                 drop_user_features=False,
                                 drop_expert=True)

# %%
# For each expert separately
X_no_e, y_no_e = import_data(DATA_PATH, segmentation_type='no',
                                 drop_user_features=False,
                                 drop_expert=False)

# %%
display(X_no.head())
display(y_no.head())
# Out:
#                                       EEPD50_100  EEPD100_150  EEPD150_200  \
# subject
# 008ba489-31ad-44d8-856b-fcf72369dc46        72.0         73.0         71.0
# 008c1c9e-aeef-40c5-846c-24f1b964f884        86.0         87.0         86.0
# 00bf9f83-2e8f-47cf-a4f2-97f2beceebc1        17.0         17.0         17.0
# 018b40a1-c109-459a-9e31-86cbd2cb3918        72.0         73.0         64.0
# 01bf156f-a8ff-48f6-9335-8a1f5bb4c1b7        64.0         65.0         66.0
#
#                                       EEPD200_250  EEPD250_300  EEPD300_350  \
# subject
# 008ba489-31ad-44d8-856b-fcf72369dc46         70.0         69.0         71.0
# 008c1c9e-aeef-40c5-846c-24f1b964f884         83.0         82.0         80.0
# 00bf9f83-2e8f-47cf-a4f2-97f2beceebc1         19.0         19.0         20.0
# 018b40a1-c109-459a-9e31-86cbd2cb3918         66.0         70.0         66.0
# 01bf156f-a8ff-48f6-9335-8a1f5bb4c1b7         69.0         67.0         70.0
#
# ...

# %% [markdown]
# ### Preprocessing

# %%
X_no = classic_preprocessing(X_no)

# %%
# Save the expert feature for split
expert = X_no_e.copy().Expert
X_no_e = classic_preprocessing(X_no_e)
X_no_e.Expert = expert.values

# %% [markdown]
# ### Split expert models

# %%
X_no_e_1, y_no_e_1, X_no_e_2, y_no_e_2, X_no_e_3, y_no_e_3 = split_experts(X_no_e, y_no_e)

# %% [markdown]
# ### Grid search one model for all

# %% [markdown]
# #### 1. Logistic regression

# %%
log_results = hyperparameter_tuning_cv(model='logistic', data=X_no, labels=y_no.Label, cv_k=5,
                                       params=LOGISTIC_PARAMS)

display(log_results)
# Out:
#                        f1_score  roc_auc_score  accuracy_score
# max_iter oversampling
# 10000    True          0.408647       0.582799        0.621687
#          False         0.192533       0.534743        0.731727
# 100000   True          0.408647       0.582799        0.621687
#          False         0.192533       0.534743        0.731727

# %%
# Best model parameters

best_log = log_results.iloc[[log_results.reset_index()['roc_auc_score'].idxmax()]]

display(best_log)
# Out:
#                        f1_score  roc_auc_score  accuracy_score
# max_iter oversampling
# 10000    True          0.408647       0.582799        0.621687

# %%
# for each expert
log_results_1 = hyperparameter_tuning_cv(model='logistic', data=X_no_e_1, labels=y_no_e_1, cv_k=5,
                                       params=LOGISTIC_PARAMS)
log_results_2 = hyperparameter_tuning_cv(model='logistic', data=X_no_e_2, labels=y_no_e_2, cv_k=5,
                                       params=LOGISTIC_PARAMS)
log_results_3 = hyperparameter_tuning_cv(model='logistic', data=X_no_e_3, labels=y_no_e_3, cv_k=5,
                                       params=LOGISTIC_PARAMS)

# %%
# Best model parameters

best_log_1 = log_results_1.iloc[[log_results_1.reset_index()['roc_auc_score'].idxmax()]]
best_log_2 = log_results_2.iloc[[log_results_2.reset_index()['roc_auc_score'].idxmax()]]
best_log_3 = log_results_3.iloc[[log_results_3.reset_index()['roc_auc_score'].idxmax()]]

display(best_log_1, best_log_2, best_log_3)
# Out:
#                        f1_score  roc_auc_score  accuracy_score
# max_iter oversampling
# 10000    True          0.326067       0.620045        0.761333
#                        f1_score  roc_auc_score  accuracy_score
# max_iter oversampling
# 10000    False         0.019347       0.485809        0.784946
#                        f1_score  roc_auc_score  accuracy_score
# max_iter oversampling
# 10000    False         0.550434       0.604468        0.612195

# %% [markdown]
# #### 2. Linear Discriminant Analysis

# %%
lda_results = hyperparameter_tuning_cv(model='lda', data=X_no, labels=y_no.Label, cv_k=5,
                                       params=LDA_PARAMS)

display(lda_results)
# Out:
#               f1_score  roc_auc_score  accuracy_score
# oversampling
# True          0.413078       0.585771        0.622892
# False         0.185544       0.533430        0.732129

# %%
# Best model parameters

best_lda = lda_results.iloc[[lda_results.reset_index()['roc_auc_score'].idxmax()]]

display(best_lda)
# Out:
#               f1_score  roc_auc_score  accuracy_score
# oversampling
# True          0.413078       0.585771        0.622892

# %%
# For each expert
lda_results_1 = hyperparameter_tuning_cv(model='lda', data=X_no_e_1, labels=y_no_e_1, cv_k=5,
                                       params=LDA_PARAMS)
lda_results_2 = hyperparameter_tuning_cv(model='lda', data=X_no_e_2, labels=y_no_e_2, cv_k=5,
                                       params=LDA_PARAMS)
lda_results_3 = hyperparameter_tuning_cv(model='lda', data=X_no_e_3, labels=y_no_e_3, cv_k=5,
                                       params=LDA_PARAMS)

# %%
best_lda_1 = lda_results_1.iloc[[lda_results_1.reset_index()['roc_auc_score'].idxmax()]]
best_lda_2 = lda_results_2.iloc[[lda_results_2.reset_index()['roc_auc_score'].idxmax()]]
best_lda_3 = lda_results_3.iloc[[lda_results_3.reset_index()['roc_auc_score'].idxmax()]]

display(best_lda_1, best_lda_2, best_lda_3)
# Out:
#               f1_score  roc_auc_score  accuracy_score
# oversampling
# True          0.382212       0.668521           0.756
#               f1_score  roc_auc_score  accuracy_score
# oversampling
# False         0.038163       0.490414        0.784946
#               f1_score  roc_auc_score  accuracy_score
# oversampling
# False         0.528299       0.588553        0.597561

# %% [markdown]
# #### 3. K-nearest Neighbors

# %%
knn_results = hyperparameter_tuning_cv(model='knn', data=X_no, labels=y_no.Label, cv_k=5,
                                       params=KNN_PARAMS)

display(knn_results)
# Out:
#                           f1_score  roc_auc_score  accuracy_score
# n_neighbors oversampling
# 1           True          0.360763       0.521631        0.523293
#             False         0.312386       0.529177        0.625703
# 2           True          0.348879       0.534690        0.586747
#             False         0.165572       0.518326        0.713655
# 3           True          0.393221       0.534200        0.480723
#             False         0.282056       0.532830        0.667068
# 4           True          0.377053       0.533423        0.523293
#             False         0.149369       0.511440        0.708835
# 5           True          0.409438       0.545378        0.464659
#             False         0.235353       0.522348        0.681928
# 6           True          0.398727       0.543809        0.496386
#             False         0.130211       0.508265        0.711245
# 7           True          0.408814       0.539929        0.445382
# ...

# %%
# Best model parameters

best_knn = knn_results.iloc[[knn_results.reset_index()['roc_auc_score'].idxmax()]]

display(best_knn)
# Out:
#                           f1_score  roc_auc_score  accuracy_score
# n_neighbors oversampling
# 14          True          0.424603       0.557228        0.453815

# %%
knn_results_1 = hyperparameter_tuning_cv(model='knn', data=X_no_e_1, labels=y_no_e_1, cv_k=5, params=KNN_PARAMS)
knn_results_2 = hyperparameter_tuning_cv(model='knn', data=X_no_e_2, labels=y_no_e_2, cv_k=5, params=KNN_PARAMS)
knn_results_3 = hyperparameter_tuning_cv(model='knn', data=X_no_e_3, labels=y_no_e_3, cv_k=5, params=KNN_PARAMS)

# %%
best_knn_1 = knn_results_1.iloc[[knn_results_1.reset_index()['roc_auc_score'].idxmax()]]
best_knn_2 = knn_results_2.iloc[[knn_results_2.reset_index()['roc_auc_score'].idxmax()]]
best_knn_3 = knn_results_3.iloc[[knn_results_3.reset_index()['roc_auc_score'].idxmax()]]

display(best_knn_1, best_knn_2, best_knn_3)
# Out:
#                           f1_score  roc_auc_score  accuracy_score
# n_neighbors oversampling
# 8           True          0.280775       0.586916        0.522667
#                           f1_score  roc_auc_score  accuracy_score
# n_neighbors oversampling
# 7           True          0.303773       0.518807        0.392473
#                           f1_score  roc_auc_score  accuracy_score
# n_neighbors oversampling
# 11          False         0.524126        0.58413        0.591463

# %% [markdown]
# #### 4. Support Vector Classifier

# %%
svc_results = hyperparameter_tuning_cv(model='svc', data=X_no, labels=y_no.Label, cv_k=5,
                                       params=SVC_PARAMS)

display(svc_results)
# Out:
#                            f1_score  roc_auc_score  accuracy_score
# kernel gamma oversampling
# linear 0.10  True          0.404506       0.580025        0.621285
#              False         0.000000       0.500000        0.739357
# rbf    0.10  True          0.101741       0.513639        0.731325
#              False         0.011852       0.500989        0.737751
# linear 0.01  True          0.404506       0.580025        0.621285
#              False         0.000000       0.500000        0.739357
# rbf    0.01  True          0.377949       0.566125        0.631727
#              False         0.000000       0.500000        0.739357

# %%
# Best model parameters

best_svc = svc_results.iloc[[svc_results.reset_index()['roc_auc_score'].idxmax()]]

display(best_svc)
# Out:
#                            f1_score  roc_auc_score  accuracy_score
# kernel gamma oversampling
# linear 0.1   True          0.404506       0.580025        0.621285

# %%
svc_results_1 = hyperparameter_tuning_cv(model='svc', data=X_no_e_1, labels=y_no_e_1, cv_k=5, params=SVC_PARAMS)
svc_results_2 = hyperparameter_tuning_cv(model='svc', data=X_no_e_2, labels=y_no_e_2, cv_k=5, params=SVC_PARAMS)
svc_results_3 = hyperparameter_tuning_cv(model='svc', data=X_no_e_3, labels=y_no_e_3, cv_k=5, params=SVC_PARAMS)

# %%
best_svc_1 = svc_results_1.iloc[[svc_results_1.reset_index()['roc_auc_score'].idxmax()]]
best_svc_2 = svc_results_2.iloc[[svc_results_2.reset_index()['roc_auc_score'].idxmax()]]
best_svc_3 = svc_results_3.iloc[[svc_results_3.reset_index()['roc_auc_score'].idxmax()]]


display(best_svc_1, best_svc_2, best_svc_3)
# Out:
#                            f1_score  roc_auc_score  accuracy_score
# kernel gamma oversampling
# rbf    0.01  True          0.357937        0.63774        0.789333
#                            f1_score  roc_auc_score  accuracy_score
# kernel gamma oversampling
# rbf    0.01  True          0.240752       0.520478        0.662366
#                            f1_score  roc_auc_score  accuracy_score
# kernel gamma oversampling
# rbf    0.01  True           0.57926       0.617861        0.620732

# %% [markdown]
# #### 5. Naive Bayes Classifier

# %%
nb_results = hyperparameter_tuning_cv(model='naive_bayes', data=X_no, labels=y_no.Label, cv_k=5,
                                       params=NAIVE_BAYES_PARAMS)

display(nb_results)
# Out:
#               f1_score  roc_auc_score  accuracy_score
# oversampling
# True          0.401902       0.577167        0.616466
# False         0.354128       0.558401        0.646988

# %%
# Best model parameters

best_nb = nb_results.iloc[[nb_results.reset_index()['roc_auc_score'].idxmax()]]

display(best_nb)
# Out:
#               f1_score  roc_auc_score  accuracy_score
# oversampling
# True          0.401902       0.577167        0.616466

# %%
nb_results_1 = hyperparameter_tuning_cv(model='naive_bayes', data=X_no_e_1, labels=y_no_e_1, cv_k=5, params=NAIVE_BAYES_PARAMS)
nb_results_2 = hyperparameter_tuning_cv(model='naive_bayes', data=X_no_e_2, labels=y_no_e_2, cv_k=5, params=NAIVE_BAYES_PARAMS)
nb_results_3 = hyperparameter_tuning_cv(model='naive_bayes', data=X_no_e_3, labels=y_no_e_3, cv_k=5, params=NAIVE_BAYES_PARAMS)

# %%
best_nb_1 = nb_results_1.iloc[[nb_results_1.reset_index()['roc_auc_score'].idxmax()]]
best_nb_2 = nb_results_2.iloc[[nb_results_2.reset_index()['roc_auc_score'].idxmax()]]
best_nb_3 = nb_results_3.iloc[[nb_results_3.reset_index()['roc_auc_score'].idxmax()]]

display(best_nb_1, best_nb_2, best_nb_3)
# Out:
#               f1_score  roc_auc_score  accuracy_score
# oversampling
# False         0.326175       0.626785           0.736
#               f1_score  roc_auc_score  accuracy_score
# oversampling
# True          0.320846       0.572497        0.648387
#               f1_score  roc_auc_score  accuracy_score
# oversampling
# True          0.537577       0.599754        0.608537

# %% [markdown]
# #### 6. Decision Tree

# %%
dt_results = hyperparameter_tuning_cv(model='decision_tree', data=X_no, labels=y_no.Label, cv_k=5,
                                       params=DECISION_TREE_PARAMS)

display(dt_results)
# Out:
#                         f1_score  roc_auc_score  accuracy_score
# max_depth oversampling
# 3         True          0.371066       0.537780        0.534137
#           False         0.105944       0.513189        0.727711
# 5         True          0.364772       0.541856        0.571888
#           False         0.166755       0.513010        0.700000
# 7         True          0.372533       0.543830        0.567871
#           False         0.223680       0.514894        0.673896

# %%
# Best model parameters

best_dt = dt_results.iloc[[dt_results.reset_index()['roc_auc_score'].idxmax()]]

display(best_dt)
# Out:
#                         f1_score  roc_auc_score  accuracy_score
# max_depth oversampling
# 7         True          0.372533        0.54383        0.567871

# %%
dt_results_1 = hyperparameter_tuning_cv(model='decision_tree', data=X_no_e_1, labels=y_no_e_1, cv_k=5, params=DECISION_TREE_PARAMS)
dt_results_2 = hyperparameter_tuning_cv(model='decision_tree', data=X_no_e_2, labels=y_no_e_2, cv_k=5, params=DECISION_TREE_PARAMS)
dt_results_3 = hyperparameter_tuning_cv(model='decision_tree', data=X_no_e_3, labels=y_no_e_3, cv_k=5, params=DECISION_TREE_PARAMS)

# %%
best_dt_1 = dt_results_1.iloc[[dt_results_1.reset_index()['roc_auc_score'].idxmax()]]
best_dt_2 = dt_results_2.iloc[[dt_results_2.reset_index()['roc_auc_score'].idxmax()]]
best_dt_3 = dt_results_3.iloc[[dt_results_3.reset_index()['roc_auc_score'].idxmax()]]

display(best_dt_1, best_dt_2, best_dt_3)
# Out:
#                         f1_score  roc_auc_score  accuracy_score
# max_depth oversampling
# 3         True          0.272713       0.580284        0.677333
#                         f1_score  roc_auc_score  accuracy_score
# max_depth oversampling
# 7         True          0.308454       0.555627        0.648387
#                         f1_score  roc_auc_score  accuracy_score
# max_depth oversampling
# 3         False         0.481446       0.581004        0.597561

# %% [markdown]
# #### 7. Random Forest

# %%
rf_results = hyperparameter_tuning_cv(model='random_forest', data=X_no, labels=y_no.Label, cv_k=5,
                                       params=RANDOM_FOREST_PARAMS)

display(rf_results)
# Out:
#                                      f1_score  roc_auc_score  accuracy_score
# max_depth n_estimators oversampling
# 3         3            True          0.379902       0.545483        0.555823
#                        False         0.042886       0.500814        0.729317
#           5            True          0.393252       0.553178        0.549398
#                        False         0.029754       0.503038        0.736145
#           7            True          0.396696       0.564560        0.585542
#                        False         0.026376       0.503959        0.738554
# 5         3            True          0.389253       0.558497        0.581124
#                        False         0.121020       0.509287        0.717269
#           5            True          0.389292       0.561857        0.592369
#                        False         0.079313       0.508799        0.730924
#           7            True          0.413597       0.582968        0.604819
# ...

# %%
# Best model parameters

best_rf = rf_results.iloc[[rf_results.reset_index()['roc_auc_score'].idxmax()]]

display(best_rf)
# Out:
#                                      f1_score  roc_auc_score  accuracy_score
# max_depth n_estimators oversampling
# 5         7            True          0.413597       0.582968        0.604819

# %%
rf_results_1 = hyperparameter_tuning_cv(model='random_forest', data=X_no_e_1, labels=y_no_e_1, cv_k=5, params=RANDOM_FOREST_PARAMS)
rf_results_2 = hyperparameter_tuning_cv(model='random_forest', data=X_no_e_2, labels=y_no_e_2, cv_k=5, params=RANDOM_FOREST_PARAMS)
rf_results_3 = hyperparameter_tuning_cv(model='random_forest', data=X_no_e_3, labels=y_no_e_3, cv_k=5, params=RANDOM_FOREST_PARAMS)

# %%
best_rf_1 = rf_results_1.iloc[[rf_results_1.reset_index()['roc_auc_score'].idxmax()]]
best_rf_2 = rf_results_2.iloc[[rf_results_2.reset_index()['roc_auc_score'].idxmax()]]
best_rf_3 = rf_results_3.iloc[[rf_results_3.reset_index()['roc_auc_score'].idxmax()]]

display(best_rf_1, best_rf_2, best_rf_3)
# Out:
#                                      f1_score  roc_auc_score  accuracy_score
# max_depth n_estimators oversampling
# 3         7            True          0.369727       0.663744            0.74
#                                      f1_score  roc_auc_score  accuracy_score
# max_depth n_estimators oversampling
# 5         7            True          0.245282       0.517691        0.645161
#                                      f1_score  roc_auc_score  accuracy_score
# max_depth n_estimators oversampling
# 3         7            False         0.551011       0.610096        0.619512

# %% [markdown]
# #### 8. Gradient Boosting

# %%
gb_results = hyperparameter_tuning_cv(model='gradient_boosting', data=X_no, labels=y_no.Label, cv_k=5,
                                       params=GRADIENT_BOOSTING_PARAMS)

display(gb_results)
# Out:
#                                      f1_score  roc_auc_score  accuracy_score
# max_depth n_estimators oversampling
# 3         3            True          0.382120       0.553788        0.571084
#                        False         0.000000       0.500000        0.739357
#           5            True          0.389040       0.562743        0.586747
#                        False         0.003077       0.500248        0.738956
#           7            True          0.405173       0.578147        0.609237
#                        False         0.006107       0.500501        0.738554
# 5         3            True          0.382986       0.562119        0.599598
#                        False         0.000000       0.500000        0.739357
#           5            True          0.388496       0.569730        0.618474
#                        False         0.009400       0.501321        0.738956
#           7            True          0.378122       0.564101        0.623293
# ...

# %%
# Best model parameters

best_gb = gb_results.iloc[[gb_results.reset_index()['roc_auc_score'].idxmax()]]

display(best_gb)
# Out:
#                                      f1_score  roc_auc_score  accuracy_score
# max_depth n_estimators oversampling
# 3         7            True          0.405173       0.578147        0.609237

# %%
gb_results_1 = hyperparameter_tuning_cv(model='gradient_boosting', data=X_no_e_1, labels=y_no_e_1, cv_k=5, params=GRADIENT_BOOSTING_PARAMS)
gb_results_2 = hyperparameter_tuning_cv(model='gradient_boosting', data=X_no_e_2, labels=y_no_e_2, cv_k=5, params=GRADIENT_BOOSTING_PARAMS)
gb_results_3 = hyperparameter_tuning_cv(model='gradient_boosting', data=X_no_e_3, labels=y_no_e_3, cv_k=5, params=GRADIENT_BOOSTING_PARAMS)

# %%
best_gb_1 = gb_results_1.iloc[[gb_results_1.reset_index()['roc_auc_score'].idxmax()]]
best_gb_2 = gb_results_2.iloc[[gb_results_2.reset_index()['roc_auc_score'].idxmax()]]
best_gb_3 = gb_results_3.iloc[[gb_results_3.reset_index()['roc_auc_score'].idxmax()]]
display(best_gb_1, best_gb_2, best_gb_3)
# Out:
#                                      f1_score  roc_auc_score  accuracy_score
# max_depth n_estimators oversampling
# 3         3            True          0.308779       0.612096        0.706667
#                                      f1_score  roc_auc_score  accuracy_score
# max_depth n_estimators oversampling
# 7         5            True          0.282354       0.551564        0.682796
#                                      f1_score  roc_auc_score  accuracy_score
# max_depth n_estimators oversampling
# 3         5            False           0.4913       0.600351        0.618293

# %% [markdown]
# ### Results

# %%
display('logistic', best_log)
display('lda', best_lda)
display('knn', best_knn)
display('svc', best_svc)
display('naive_bayes', best_nb)
display('decision_tree', best_dt)
display('random_forest', best_rf)
display('gradient_boosting', best_gb)
# Out:
# 'logistic'
#                        f1_score  roc_auc_score  accuracy_score
# max_iter oversampling
# 10000    True          0.408647       0.582799        0.621687
# 'lda'
#               f1_score  roc_auc_score  accuracy_score
# oversampling
# True          0.413078       0.585771        0.622892
# 'knn'
#                           f1_score  roc_auc_score  accuracy_score
# n_neighbors oversampling
# 13          True          0.426986       0.554643        0.429719
# 'svc'
#                            f1_score  roc_auc_score  accuracy_score
# kernel gamma oversampling
# linear 0.1   True          0.404506       0.580025        0.621285
# 'naive_bayes'
#               f1_score  roc_auc_score  accuracy_score
# oversampling
# True          0.401902       0.577167        0.616466
# 'decision_tree'
#                         f1_score  roc_auc_score  accuracy_score
# max_depth oversampling
# 7         True          0.372533        0.54383        0.567871
# 'random_forest'
# ...

# %%
# Results expert features
# First row is Expert 1, second Expert 2, third Expert 3
display('logistic', pd.concat([best_log_1,best_log_2,best_log_3]))
display('lda', pd.concat([best_lda_1,best_lda_2,best_lda_3]))
display('knn', pd.concat([best_knn_1,best_knn_2,best_knn_3]))
display('svc', pd.concat([best_svc_1,best_svc_2,best_svc_3]))
display('naive_bayes', pd.concat([best_nb_1,best_nb_2,best_nb_3]))
display('decision_tree', pd.concat([best_dt_1,best_dt_2,best_dt_3]))
display('random_forest', pd.concat([best_rf_1,best_rf_2,best_rf_3]))
display('gradient_boosting', pd.concat([best_gb_1,best_gb_2,best_gb_3]))
# Out:
# 'logistic'
#                        f1_score  roc_auc_score  accuracy_score
# max_iter oversampling
# 10000    True          0.326067       0.620045        0.761333
#          False         0.019347       0.485809        0.784946
#          False         0.550434       0.604468        0.612195
# 'lda'
#               f1_score  roc_auc_score  accuracy_score
# oversampling
# True          0.382212       0.668521        0.756000
# False         0.038163       0.490414        0.784946
# False         0.528299       0.588553        0.597561
# 'knn'
#                           f1_score  roc_auc_score  accuracy_score
# n_neighbors oversampling
# 8           True          0.280775       0.586916        0.522667
# 7           True          0.303773       0.518807        0.392473
# 11          False         0.524126       0.584130        0.591463
# 'svc'
#                            f1_score  roc_auc_score  accuracy_score
# kernel gamma oversampling
# ...

# %% [markdown]
# ### Conclusions
#
# TODO

# %%
# Save the best results for:
# ALL features, ONE model

# ALL features, 3 models

# %%
# NOT ALL features, ONE model

# NOT ALL features, 3 models
